# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#### import our data

# %%
data = pd.read_csv("C:/Users/Aslam Khan/Desktop/EastWestAirlines.csv")

# %%
data.head()
df=data
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.describe()## we have describe the neumerical statistic
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
df.columns#### definbe the columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %%
df.isnull().sum()## find the misising values
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
df.shape## define the row and columns our data
# Out:
# (3999, 12)

# %%
df.info()## defin null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
x = df[['ID#', 'Balance', 'cc1_miles', 'cc2_miles', 'cc3_miles',
       'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
       'Days_since_enroll', 'Award?']]### defin the  x and y variable
y = df['Qual_miles']

# %%
x
# Out:
#        ID#  Balance  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143          1          1          1          174
# 1        2    19244          1          1          1          215
# 2        3    41354          1          1          1         4123
# 3        4    14776          1          1          1          500
# 4        5    97752          4          1          1        43300
# ...    ...      ...        ...        ...        ...          ...
# 3994  4017    18476          1          1          1         8525
# 3995  4018    64385          1          1          1          981
# 3996  4019    73597          3          1          1        25447
# 3997  4020    54899          1          1          1          500
# 3998  4021     3016          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3994    0
# 3995    0
# 3996    0
# 3997    0
# 3998    0
# Name: Qual_miles, Length: 3999, dtype: int64

# %%
df[data['Balance'].duplicated().values]#### to check any weather row are duplicated
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 848    859    20126           0          1          1          1            0
# 1010  1021    11449           0          1          1          1        24415
# 1159  1171    31769           0          1          1          1            0
# 1230  1243    97752           0          1          1          1         3676
# 1231  1244     8327           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 3918  3941    17481           0          1          1          1            0
# 3919  3942     5000           0          1          1          1         5000
# 3947  3970    45533           0          2          1          1        12247
# 3960  3983    24917           0          1          1          1         3948
# 3988  4011     5000           0          1          1          1         2125
#
# ...

# %%
Flight_trans_12= df['cc1_miles'].sum()#### define the,cc1_miles
Flight_trans_12
# Out:
# 8236

# %%
Flight_miles_12mo = df['cc2_miles'].sum()#### define the cc2_miles Flight_miles_12mo
Flight_miles_12mo
# Out:
# 4057

# %%
cc3_miles = df['cc3_miles'].sum()#### define the cc3_miles Flight_miles_12mo miles
cc3_miles
# Out:
# 4048

# %%
plt.figure(figsize=(20, 10))### define the  heatmap
sns.heatmap(df.corr() ,annot=True, cmap='viridis', linewidths=.5)
# Out:
# <AxesSubplot:>

# %%
### visualize our plot

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x = 'Flight_miles_12mo' , y = 'Flight_trans_12', hue =  'Balance' ,data=data)
# Out:
# <AxesSubplot:xlabel='Flight_miles_12mo', ylabel='Flight_trans_12'>

# %%
from sklearn.cluster import KMeans#### import the  package

# %%
cluster = KMeans(n_clusters=3)###  we have fit our model in cluster
cluster.fit(x)

p= cluster.predict(x)### predict the cluster
p , len(p)
# Out:
# (array([1, 1, 1, ..., 1, 1, 1]), 3999)

# %%
wcss = []
for i in range(1,10):
    km = KMeans(n_clusters=i, max_iter=200)
    km.fit(x)
    wcss.append(km.inertia_)

# %%
wcss

plt.plot(range(1, 10), wcss)## visualize the plot
plt.show()

# %% [markdown]
# ### fiting the KMeans to data set

# %%
cluster = KMeans(n_clusters=5)
cluster.fit(x)

p1= cluster.predict(x)
p1 , len(p1)
# Out:
# (array([1, 1, 1, ..., 0, 1, 1]), 3999)

# %%
df['cluster'] = p1

# %%
print(df.head())
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    cluster
# 0        1
# 1        1
# 2        1
# ...

# %%
df[df['cluster']==1]##
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 5        6    16420           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 3993  4016     3974           0          1          1          1          365
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
print(df['cluster'].value_counts())
# Out:
# 1    2502
# 0    1048
# 4     342
# 2      88
# 3      19
# Name: cluster, dtype: int64

# %%
print(df['cluster'].value_counts(normalize=True)*100)
# Out:
# 1    62.565641
# 0    26.206552
# 4     8.552138
# 2     2.200550
# 3     0.475119
# Name: cluster, dtype: float64

# %%
### import the package

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
sc = StandardScaler()
x_scaled = sc.fit_transform(x)
x_scaled
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
### visualize the scattter plot
sns.scatterplot(x = 'Balance' , y = 'Award?', hue =  'cluster' ,data=data, palette= 'summer')
# Out:
# <AxesSubplot:xlabel='Balance', ylabel='Award?'>

# %%
### silhouette score -- measure how cluster a point is to own cluster caompared to other cluster
from sklearn.metrics import silhouette_score

# %%
labels = cluster.labels_
silhouette_score(x , labels, metric='euclidean')## define the silhouette score
# Out:
# 0.5418644867615849

# %% [markdown]
# ### done
